# %% [markdown]
# Name: Utkarsh Kumar Nigam

# %% [markdown]
# Enrollnment no:2503051240119

# %% [markdown]
# Roll no:27

# %% [markdown]
# Practical 1: OOP, Exception Handling, and File Operations

# %% [markdown]
# Aim:
# To demonstrate object-oriented programming concepts, handle
# exceptions, and perform file read/write operations in Python.

# %%
class Student:
    # Constructor
    def __init__(self, name, marks):
        self.name = name
        self.marks = marks
    # Method to display details
    def display(self):
        print(f"Name: {self.name}")
        print(f"Marks: {self.marks}")
    # Method to check result
    def result(self):
        return "Pass" if self.marks >= 40 else "Fail"
# Creating objects
s1 = Student("Rasna", 85)
s2 = Student("Amit", 35)
# Calling methods
s1.display()
print("Result:", s1.result())
s2.display()
print("Result:", s2.result())
# Out:
# Name: Rasna
# Marks: 85
# Result: Pass
# Name: Amit
# Marks: 35
# Result: Fail

# %%
try:
 a = int(input("Enter numerator: "))
 b = int(input("Enter denominator: "))
 result = a / b
 print("Result:", result)
except ZeroDivisionError:
 print("Error: Division by zero is not allowed")
except ValueError:
 print("Error: Please enter valid integers")
finally:
 print("Execution completed")
# Out:
# Enter numerator: 5
# Enter denominator: 6
# Result: 0.8333333333333334
# Execution completed

# %%
try:
    with open("students.txt", "w") as file:
        file.write("Name: Rasna\n")
        file.write("Marks: 85\n")
        print("Data written successfully")
except IOError:
    print("File write error")
# Out:
# Data written successfully

# %%
try:
    with open("students.txt", "r") as file:
        content = file.read()
        print("File Content:\n", content)
except FileNotFoundError:
    print("File not found")
# Out:
# File Content:
#  Name: Rasna
# Marks: 85

# %%
try:
    with open("students.txt", "a") as file:
        file.write("Result: Pass\n")
        print("Data appended successfully")
except IOError:
    print("File write error")
# Out:
# Data appended successfully
